# %% [markdown]
# ## Question:
# What is the average petal length for each species, in order: setosa, versicolor, virginica??

# %%
import pandas as pd

# %%
Iris = pd.read_csv("iris.csv")

# %%
print(Iris.head(4))
print(Iris.tail(4))
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
print(Iris.shape)
# Out:
# (150, 5)

# %%
print(Iris.Species.value_counts())
# Out:
# virginica     50
# setosa        50
# versicolor    50
# Name: Species, dtype: int64

# %%
Iris_matrix = pd.DataFrame.as_matrix(Iris[['Sepal.Length','Sepal.Width','Petal.Length','Petal.Width']])

# %%
print(Iris.describe())
# Out:
#        Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
print('pd: {}'.format(pd.__version__))
# Out:
# pd: 0.20.1

# %%
print(Iris.groupby('Species').size())
# Out:
# Species
# setosa        50
# versicolor    50
# virginica     50
# dtype: int64

# %%
from pandas.tools.plotting import scatter_matrix

# %%
pd.plotting.scatter_matrix(Iris[Iris.Species == "setosa"])
pd.plotting.scatter_matrix(Iris[Iris.Species == "versicolor"])
pd.plotting.scatter_matrix(Iris[Iris.Species == "virginica"])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000D53D358>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000DB25F98>]], dtype=object)

# %%
Iris_matrix = pd.DataFrame.as_matrix(Iris[['Petal.Length']])

# %%
print (Iris_matrix)
# Out:
# [[ 1.4]
#  [ 1.4]
#  [ 1.3]
#  [ 1.5]
#  [ 1.4]
#  [ 1.7]
#  [ 1.4]
#  [ 1.5]
#  [ 1.4]
#  [ 1.5]
#  [ 1.5]
#  [ 1.6]
#  [ 1.4]
#  [ 1.1]
#  [ 1.2]
#  [ 1.5]
#  [ 1.3]
#  [ 1.4]
#  [ 1.7]
#  [ 1.5]
#  [ 1.7]
#  [ 1.5]
#  [ 1. ]
#  [ 1.7]
#  [ 1.9]
#  [ 1.6]
#  [ 1.6]
#  [ 1.5]
#  [ 1.4]
#  [ 1.6]
#  [ 1.6]
#  [ 1.5]
#  [ 1.5]
#  [ 1.4]
#  [ 1.5]
#  [ 1.2]
#  [ 1.3]
#  [ 1.5]
#  [ 1.3]
#  [ 1.5]
#  [ 1.3]
#  [ 1.3]
#  [ 1.3]
#  [ 1.6]
#  [ 1.9]
#  [ 1.4]
#  [ 1.6]
#  [ 1.4]
#  [ 1.5]
#  [ 1.4]
#  [ 4.7]
#  [ 4.5]
#  [ 4.9]
#  [ 4. ]
#  [ 4.6]
#  [ 4.5]
#  [ 4.7]
#  [ 3.3]
#  [ 4.6]
#  [ 3.9]
#  [ 3.5]
#  [ 4.2]
#  [ 4. ]
#  [ 4.7]
#  [ 3.6]
#  [ 4.4]
#  [ 4.5]
#  [ 4.1]
#  [ 4.5]
#  [ 3.9]
#  [ 4.8]
#  [ 4. ]
#  [ 4.9]
#  [ 4.7]
#  [ 4.3]
#  [ 4.4]
#  [ 4.8]
#  [ 5. ]
#  [ 4.5]
#  [ 3.5]
#  [ 3.8]
#  [ 3.7]
#  [ 3.9]
#  [ 5.1]
#  [ 4.5]
#  [ 4.5]
#  [ 4.7]
#  [ 4.4]
#  [ 4.1]
#  [ 4. ]
#  [ 4.4]
#  [ 4.6]
#  [ 4. ]
#  [ 3.3]
#  [ 4.2]
#  [ 4.2]
#  [ 4.2]
#  [ 4.3]
#  [ 3. ]
#  [ 4.1]
# ...

# %%
sesota=Iris.loc[0:49]

# %%
versicolor =Iris.loc[50:99]

# %%
Iris.loc[50:99]
# Out:
#     Sepal.Length  Sepal.Width  Petal.Length  Petal.Width     Species
# 50           7.0          3.2           4.7          1.4  versicolor
# 51           6.4          3.2           4.5          1.5  versicolor
# 52           6.9          3.1           4.9          1.5  versicolor
# 53           5.5          2.3           4.0          1.3  versicolor
# 54           6.5          2.8           4.6          1.5  versicolor
# 55           5.7          2.8           4.5          1.3  versicolor
# 56           6.3          3.3           4.7          1.6  versicolor
# 57           4.9          2.4           3.3          1.0  versicolor
# 58           6.6          2.9           4.6          1.3  versicolor
# 59           5.2          2.7           3.9          1.4  versicolor
# 60           5.0          2.0           3.5          1.0  versicolor
# 61           5.9          3.0           4.2          1.5  versicolor
# 62           6.0          2.2           4.0          1.0  versicolor
# ...

# %%
virginica =Iris.loc[100:149]

# %%
Iris.loc[100:149]
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 100           6.3          3.3           6.0          2.5  virginica
# 101           5.8          2.7           5.1          1.9  virginica
# 102           7.1          3.0           5.9          2.1  virginica
# 103           6.3          2.9           5.6          1.8  virginica
# 104           6.5          3.0           5.8          2.2  virginica
# 105           7.6          3.0           6.6          2.1  virginica
# 106           4.9          2.5           4.5          1.7  virginica
# 107           7.3          2.9           6.3          1.8  virginica
# 108           6.7          2.5           5.8          1.8  virginica
# 109           7.2          3.6           6.1          2.5  virginica
# 110           6.5          3.2           5.1          2.0  virginica
# 111           6.4          2.7           5.3          1.9  virginica
# 112           6.8          3.0           5.5          2.1  virginica
# ...

# %%
Iris["Petal.Length"][0:50]
# Out:
# 0     1.4
# 1     1.4
# 2     1.3
# 3     1.5
# 4     1.4
# 5     1.7
# 6     1.4
# 7     1.5
# 8     1.4
# 9     1.5
# 10    1.5
# 11    1.6
# 12    1.4
# 13    1.1
# 14    1.2
# 15    1.5
# 16    1.3
# 17    1.4
# 18    1.7
# 19    1.5
# 20    1.7
# 21    1.5
# 22    1.0
# 23    1.7
# 24    1.9
# 25    1.6
# 26    1.6
# 27    1.5
# 28    1.4
# 29    1.6
# 30    1.6
# 31    1.5
# 32    1.5
# 33    1.4
# 34    1.5
# 35    1.2
# 36    1.3
# 37    1.5
# 38    1.3
# 39    1.5
# 40    1.3
# 41    1.3
# 42    1.3
# 43    1.6
# 44    1.9
# 45    1.4
# 46    1.6
# 47    1.4
# 48    1.5
# 49    1.4
# Name: Petal.Length, dtype: float64

# %%
Iris["Petal.Length"][50:100]
# Out:
# 50    4.7
# 51    4.5
# 52    4.9
# 53    4.0
# 54    4.6
# 55    4.5
# 56    4.7
# 57    3.3
# 58    4.6
# 59    3.9
# 60    3.5
# 61    4.2
# 62    4.0
# 63    4.7
# 64    3.6
# 65    4.4
# 66    4.5
# 67    4.1
# 68    4.5
# 69    3.9
# 70    4.8
# 71    4.0
# 72    4.9
# 73    4.7
# 74    4.3
# 75    4.4
# 76    4.8
# 77    5.0
# 78    4.5
# 79    3.5
# 80    3.8
# 81    3.7
# 82    3.9
# 83    5.1
# 84    4.5
# 85    4.5
# 86    4.7
# 87    4.4
# 88    4.1
# 89    4.0
# 90    4.4
# 91    4.6
# 92    4.0
# 93    3.3
# 94    4.2
# 95    4.2
# 96    4.2
# 97    4.3
# 98    3.0
# 99    4.1
# Name: Petal.Length, dtype: float64

# %%
Iris["Petal.Length"][100:150]
# Out:
# 100    6.0
# 101    5.1
# 102    5.9
# 103    5.6
# 104    5.8
# 105    6.6
# 106    4.5
# 107    6.3
# 108    5.8
# 109    6.1
# 110    5.1
# 111    5.3
# 112    5.5
# 113    5.0
# 114    5.1
# 115    5.3
# 116    5.5
# 117    6.7
# 118    6.9
# 119    5.0
# 120    5.7
# 121    4.9
# 122    6.7
# 123    4.9
# 124    5.7
# 125    6.0
# 126    4.8
# 127    4.9
# 128    5.6
# 129    5.8
# 130    6.1
# 131    6.4
# 132    5.6
# 133    5.1
# 134    5.6
# 135    6.1
# 136    5.6
# 137    5.5
# 138    4.8
# 139    5.4
# 140    5.6
# 141    5.1
# 142    5.1
# 143    5.9
# 144    5.7
# 145    5.2
# 146    5.0
# 147    5.2
# 148    5.4
# 149    5.1
# Name: Petal.Length, dtype: float64

# %%
sesota_PL= Iris["Petal.Length"][0:50]

# %%
versicolor_PL= Iris["Petal.Length"][50:100]

# %%
virginica_PL= Iris["Petal.Length"][100:150]

# %%
sesota_PL.mean()
# Out:
# 1.464

# %%
versicolor_PL.mean()
# Out:
# 4.26

# %%
virginica_PL.mean()
# Out:
# 5.552
